# %%
# 有关列表的定义
bicycles = ['trek', 'cannondale', 'redline', 'specialized'] 
print(bicycles)
# Out:
# ['trek', 'cannondale', 'redline', 'specialized']

# %% [markdown]
# 访问列表元素的方式

# %%
print(bicycles[0].title())
print(bicycles[-1])
print(bicycles[:])
print(bicycles[0:-1])
# Out:
# Trek
# specialized
# ['trek', 'cannondale', 'redline', 'specialized']
# ['trek', 'cannondale', 'redline']

# %%
message = f"My first bicycle was a {bicycles[0].title()}."
print(message)
# Out:
# My first bicycle was a Trek.

# %% [markdown]
# 修改、添加和删除元素

# %%
motorcycles = ['honda', 'yamaha', 'suzuki']
motorcycles[0]='ducati'
print(motorcycles)
motorcycles.append('honda')
print('向末尾添加honda : ',motorcycles)
del motorcycles[0]
print('删除第一个元素 ducati : ',motorcycles)
motorcycles.insert(0, 'ducati')
print('向首尾插入honda : ',motorcycles)
poped_motorcycles=motorcycles.pop()
print('pop出的末尾元素 : ',poped_motorcycles)
print('pop后的原列表 : ',motorcycles)
i=1
poped_motorcycles=motorcycles.pop(i)
print(f'pop出的第{i}个元素 : ',poped_motorcycles)
print('pop后的原列表 : ',motorcycles)
motorcycles.remove('ducati')
print('After remove : ',motorcycles)

# %% [markdown]
# 组织列表

# %%
cars = ['bmw', 'audi', 'toyota', 'subaru']
cars.sort()
print(cars)
cars.sort(reverse=True)
print(cars)
cars = ['bmw', 'audi', 'toyota', 'subaru']
print(sorted(cars))
print(cars)
cars.reverse();
print(cars)

# %%
print('列表长度 : ',len(cars))
# Out:
# 列表长度 :  4

# %% [markdown]
# 操作列表

# %%
magicians = ['alice', 'david', 'carolina']
for magician in magicians:
    print(magician)
print(magician in magicians)

# %% [markdown]
# 创建数值列表

# %%
for i in range(1,5):
    print(i)
numbers=list(range(1,6))
print(numbers)
even_numbers=list(range(2,11,2))
print(even_numbers)
squares=[]
for i in range(1,11):
    squares.append(i**2)
print(squares)

# %% [markdown]
# 数值列表的简单统计计算

# %%
digits = [1, 2, 3, 4, 5, 6, 7, 8, 9, 0]
print(min(digits))
print(max(digits))
print(sum(digits))

# %%
squares=[value**2 for value in range(1,11)]
print(squares)
squares+=[value**2 for value in range(11,15)]
print(squares)

# %%
# 列表的切片
print(squares[1:-1])
print(squares[1:])
for number in squares[1:-1]:
    print(number)

# %%
my_foods = ['pizza', 'falafel', 'carrot cake']
friend_foods = my_foods
print(friend_foods)
del my_foods[0]
print(friend_foods)

my_foods = ['pizza', 'falafel', 'carrot cake']
friend_foods=my_foods[:]
del my_foods[0]
print(my_foods)
print(friend_foods)
